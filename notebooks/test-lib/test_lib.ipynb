# %% [markdown]
# # BirdCLEF 2026 — Test Lib
#
# Verifies the lib notebook output is importable (internet OFF).

# %%
import tarfile, sys
with tarfile.open('/kaggle/input/notebooks/joshgreen/birdclef-2026-lib/pkg.tar.gz', 'r:gz') as tar:
    tar.extractall('/kaggle/working')
sys.path.insert(0, '/kaggle/working/pkg')

from birdclef_2026.experiments.baseline.model import build_model
print('All imports OK')

# %%
import sys
sys.path.insert(0, '/kaggle/input/notebooks/joshgreen/birdclef-2026-lib/pkg')

from birdclef_2026.experiments.baseline.model import build_model
print('All imports OK')
