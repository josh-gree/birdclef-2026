# %% [markdown]
# # BirdCLEF 2026 — Package Wheels
#
# Utility notebook (internet ON) that installs the birdclef_2026 package and its dependencies.
# The output is used as a data source in the submission notebook for offline install.

# %%
# !pip install uv
# !uv pip install git+https://github.com/josh-gree/birdclef-2026.git --target /kaggle/working/pkg --system

# %%
# Verify the package is importable
import sys
sys.path.insert(0, '/kaggle/working/pkg')

from birdclef_2026.data.transforms import build_spectrogram_pipeline
from birdclef_2026.experiments.baseline.model import build_efficientnet_b3_backbone, build_head
print('All imports OK')
