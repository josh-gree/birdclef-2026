# %% [markdown]
# # nnAudio deps
#
# Installs nnAudio and creates a tarball for offline use in Kaggle notebooks.
# Run once, upload `nnaudio.tar.gz` as a Kaggle dataset.

# %%
# !pip install uv -q
# !uv pip install nnaudio --target /tmp/nnaudio_pkg --system -q
import tarfile
with tarfile.open('/kaggle/working/nnaudio.tar.gz', 'w:gz') as tar:
    tar.add('/tmp/nnaudio_pkg', arcname='nnaudio_pkg')
print('nnaudio.tar.gz created')

# %%
import sys
sys.path.insert(0, '/tmp/nnaudio_pkg')
from nnAudio.features import MelSpectrogram
print('nnAudio OK')
